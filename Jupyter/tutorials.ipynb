# %%
4
# Out:
# 4

# %%
2.015
# Out:
# 2.015

# %%
# Hello notice

# %%
print('Hello Python')
# Out:
# Hello Python

# %%
2 + 5
# Out:
# 7

# %%
9 - 45
# Out:
# -36

# %%
'Hello' + 'Python'
# Out:
# 'HelloPython'

# %%
42 / 7
# Out:
# 6.0

# %%
13 / 6
# Out:
# 2.1666666666666665

# %%
12 // 3
# Out:
# 4

# %%
15 // 4
# Out:
# 3

# %%
15 // 3.5
# Out:
# 4.0

# %%
3*3
# Out:
# 9

# %%
3 ** 2
# Out:
# 9

# %%
9 ** 2
# Out:
# 81

# %%
9 ** 9
# Out:
# 387420489

# %%
7 - 1 * 3 + 5 * 2
# Out:
# 14

# %%
7 - 1 * 3 + 5 / 2
# Out:
# 6.5

# %%
7 - 1 * 3 + 5 * 2 // 5
# Out:
# 6

# %%
7 % 3 # reminder is 1
# Out:
# 1

# %%
12 % 6 # reminder is 0
# Out:
# 0

# %%
(9 * 3) + 7 - 2
# Out:
# 32

# %%
7 - 1 * 3 + 5 % 2
# Out:
# 5

# %%
city = 'Berlin'

# %%
city
# Out:
# 'Berlin'

# %%
a = 23

# %%
b = 11

# %%
a + b
# Out:
# 34

# %%
a - b
# Out:
# 12

# %%
fname = 'Tom'

# %%
lname = 'Bob'

# %%
"The teacher starting new leasson his full name is {} {} ".format(fname, lname)
# Out:
# 'The teacher starting new leasson his full name is Tom Bob '

# %%
language = 'Python'
framework = 'Django'

# %%
f'We will start using {language} and for our backend using {framework}.'
# Out:
# 'We will start using Python and for our backend using Django.'

# %%
f'We will start using {language} and for our backend using {framework}.'
# Out:
# 'We will start using Python and for our backend using Django.'

# %%
'We will start {database} and for our backend using {framework}.'.format(database='MangoDB', framework='Flask')
# Out:
# 'We will start MangoDB and for our backend using Flask.'

# %%
lang = 'Python'

# %%
lang[:-1]
# Out:
# 'Pytho'

# %%
lang[2]
# Out:
# 't'

# %%
lang[0:3]
# Out:
# 'Pyt'

# %%
lang[-1]
# Out:
# 'n'

# %%
lang[1:-1]
# Out:
# 'ytho'

# %%
line = 'Welcome to Jupyter tutorials.'

# %%
line[::-1]
# Out:
# '.slairotut retypuJ ot emocleW'

# %%
cities = ['Berlin', 'Paris']

# %%
cities
# Out:
# ['Berlin', 'Paris']

# %%
cities.append('New Yourk')

# %%
cities.append('Brussel')

# %%
cities
# Out:
# ['Brussel', 'Paris', 'Berlin', 'Brussel']

# %%
cities[::-1]
# Out:
# ['Brussel', 'Berlin', 'Paris', 'Brussel']

# %%
cities.remove('New Yourk')

# %%
cities.remove('Brussel')

# %%
cities
# Out:
# ['Paris', 'Berlin', 'Brussel']

# %%
cities[1] = 'Amsterdam' # replacse 1 city to another

# %%
cities
# Out:
# ['Paris', 'Amsterdam', 'Brussel']

# %%
cities += 'Bonn'

# %%
cities
# Out:
# ['Paris', 'Amsterdam', 'Brussel', 'B', 'o', 'n', 'n']

# %%
char = ['a', 'b', 'c', [1,2,3], 'd', 'e', [0,4]]

# %%
char
# Out:
# ['a', 'b', 'c', [1, 2, 3], 'd', 'e', [0, 4]]

# %%
char[3]
# Out:
# [1, 2, 3]

# %%
char[6]
# Out:
# [0, 4]

# %%
char[6][1]
# Out:
# 4

# %%
char[3][2]
# Out:
# 3
