# %%
import sys
import matplotlib
# matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

yline = np.array([2, 18, 6, 28, 10])

plt.plot(yline, marker ='.')
plt.show()

# The two lines to make our compiler able to draw
plt.savefig(sys.stdout.buffer)
sys.stdout.flush()
# Out:
# /tmp/ipykernel_45346/2028852187.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 14
#      11 plt.show()
#      13 # The two lines to make our compiler able to draw
# ---> 14 plt.savefig(sys.stdout.buffer)
#      15 sys.stdout.flush()
#
# AttributeError: 'OutStream' object has no attribute 'buffer'
