# %%
# The three line is to make the complier able to draw
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

yline = np.array([3, 8, 1, 10])

plt.plot(yline, marker='.')
plt.savefig(sys.stdout.buffer)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 12
#       9 yline = np.array([3, 8, 1, 10])
#      11 plt.plot(yline, marker='.')
# ---> 12 plt.savefig(sys.stdout.buffer)
#
# AttributeError: 'OutStream' object has no attribute 'buffer'
