# %% [markdown]
# # Matplotlib
# pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.linspace(0, 10, 1000)
y = np.sin(x)

plt.plot(x, y)

# %%
plt.plot(y, x)

# %%
y = np.sin(x)
plt.scatter(x, y)

# %%
plt.scatter(x[:40], y[:40])

# %%
plt.scatter(x[::40], y[::40])

# %%
plt.scatter(x[::30], y[::30])

# %%
plt.scatter(x[::20], y[::20])

# %%
plt.scatter(x[::10], y[::10])

# %%
plt.scatter(x[::5], y[::5])

# %%
plt.scatter(x[::7], y[::7])

# %%
plt.plot([1, 2, 3, 4], color='yellow')
plt.ylabel('First line')

plt.plot([5, 6, 7, 8], color='red')
plt.xlabel('Second line')

plt.plot([9, 10,11, 12], color='blue')
plt.plot([2, 4, 6, 8], color='black')
plt.plot([5, 10, 15, 20], color='orange')

plt.show()

# %%
plt.plot([10, 20, 30, 40], color='yellow')
plt.ylabel('First line')

plt.plot([0, 3, 6, 9], color='red')
plt.xlabel('Second line')

plt.plot([9, 10,11, 12], color='blue')
plt.plot([2, 4, 6, 8], color='black')
plt.plot([5, 10, 15, 20], color='orange')

plt.show() # show() not need argument to add

# %%
plt.plot([40, 30, 20, 10, 0], color='yellow')
plt.ylabel('First line')

plt.plot([0, 10, 20, 30, 40], color='red')
plt.xlabel('Second line')

plt.plot([9, 10,11, 12], color='blue')
plt.plot([-40, -30, -20, -10, 0], color='black')
plt.plot([15, 10, 15, 100])

plt.show() # show() not need argument to add

# %%
plt.semilogx()
# Out:
# []

# %%
plt.plot(x, np.sin(x - 0), color='red')
plt.plot(x, np.sin(x - 10), color='g')
plt.plot(x, np.sin(x - 20), color='b')
plt.plot(x, np.sin(x - 30), color='y')

# %%
plt.plot(x, x + 0, 'g')
plt.plot(x, x + 5, 'y')
plt.plot(x, x + 10, 's')
plt.plot(x, x + 20, 'b')
plt.plot(x, x + 15, 'r')

# %%
plt.plot(x, x + 50 , color='black')
plt.plot(x, x + 40, color='yellow')
plt.plot(x, x + 30, color='green')
plt.plot(x, x + 20, color='blue')

# %%
plt.plot(x, x - (-5) , color='black')
plt.plot(x, x - (-10), color='yellow')
plt.plot(x, x - (-15), color='green')
plt.plot(x, x - (-20), color='blue')

# %%
plt.plot(x, x + 0, '-g') # >> Solid green
plt.plot(x, x + 5, '--c') # >> dashed cyan
plt.plot(x, x + 10, '-.k') # >> dashdot black
plt.plot(x, x + 20, '-b')
plt.plot(x, x + 15, ':r') # >> dotted red

# %%
plt.semilogx()
# Out:
# []

# %%
plt.plot(y, x, color='green')
plt.plot(x, np.cos(x), color='r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 plt.plot(y, x, color='green')
#       2 plt.plot(x, np.cos(x), color='r')
#
# NameError: name 'y' is not defined

# %%
plt.plot(x, y, color='green')
plt.plot(x, np.cos(x), color='r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 plt.plot(x, y, color='green')
#       2 plt.plot(x, np.cos(x), color='r')
#
# NameError: name 'x' is not defined

# %%
plt.plot(x, y, color='green')
plt.plot(y, np.cos(y), color='r')

# %%
plt.plot(x, y, color='green')
plt.plot(y, np.sin(y), color='r')

# %%
plt.plot(x, y, color='blue')
plt.plot(x, np.sin(x), color='r')

# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np 
import sklearn

from sklearn.impute import SimpleImputer
from pandas import read_excel

file_path = '/home/user/Devop/Python/Data-Science/'

file_name = file_path + "nhsTrust_nonCovidOccupiedMVBeds.csv"

readme = pd.read_csv(file_name)

# %%
readme
# Out:
#              date area_type area_code  \
# 0      2020-01-03  nhsTrust       RNS
# 1      2020-01-03  nhsTrust       RGP
# 2      2020-01-03  nhsTrust       RP5
# 3      2020-01-03  nhsTrust       RJR
# 4      2020-01-03  nhsTrust       RLT
# ...           ...       ...       ...
# 75955  2020-12-27  nhsTrust       RTP
# 75956  2020-12-27  nhsTrust       RVV
# 75957  2020-12-27  nhsTrust       RWX
# 75958  2020-12-27  nhsTrust       RCX
# 75959  2020-12-27  nhsTrust       RA9
#
#                                                area_name  \
# 0                 Northampton General Hospital NHS Trust
# 1      James Paget University Hospitals NHS Foundatio...
# 2      Doncaster and Bassetlaw Teaching Hospitals NHS...
# 3      Countess of Chester Hospital NHS Foundation Trust
# 4                        George Eliot Hospital NHS Trust
# ...                                                  ...
# 75955             Surrey and Sussex Healthcare NHS Trust
# ...

# %%
readme.head(45)
# Out:
#           date area_type area_code  \
# 0   2020-01-03  nhsTrust       RNS
# 1   2020-01-03  nhsTrust       RGP
# 2   2020-01-03  nhsTrust       RP5
# 3   2020-01-03  nhsTrust       RJR
# 4   2020-01-03  nhsTrust       RLT
# 5   2020-01-03  nhsTrust       RXP
# 6   2020-01-03  nhsTrust       RKL
# 7   2020-01-03  nhsTrust      NRR8
# 8   2020-01-03  nhsTrust       RH8
# 9   2020-01-03  nhsTrust       RXL
# 10  2020-01-03  nhsTrust       RR8
# 11  2020-01-03  nhsTrust       REM
# 12  2020-01-03  nhsTrust       RNK
# 13  2020-01-03  nhsTrust       RGT
# 14  2020-01-03  nhsTrust      NRH8
# 15  2020-01-03  nhsTrust       RXK
# 16  2020-01-03  nhsTrust       R1H
# 17  2020-01-03  nhsTrust       RT2
# 18  2020-01-03  nhsTrust       RGM
# 19  2020-01-03  nhsTrust       RWJ
# 20  2020-01-03  nhsTrust       RLY
# 21  2020-01-03  nhsTrust       RR7
# 22  2020-01-03  nhsTrust       RVY
# 23  2020-01-03  nhsTrust       RWP
# 24  2020-01-03  nhsTrust       REP
# ...

# %%
readme.drop(['area_type', 'area_name', 'metric_name'], axis=1, inplace=True)

# %%
readme.head(20)
# Out:
#           date area_code                  metric  value
# 0   2020-01-03       RNS  nonCovidOccupiedMVBeds    NaN
# 1   2020-01-03       RGP  nonCovidOccupiedMVBeds    NaN
# 2   2020-01-03       RP5  nonCovidOccupiedMVBeds    NaN
# 3   2020-01-03       RJR  nonCovidOccupiedMVBeds    NaN
# 4   2020-01-03       RLT  nonCovidOccupiedMVBeds    NaN
# 5   2020-01-03       RXP  nonCovidOccupiedMVBeds    NaN
# 6   2020-01-03       RKL  nonCovidOccupiedMVBeds    NaN
# 7   2020-01-03      NRR8  nonCovidOccupiedMVBeds    NaN
# 8   2020-01-03       RH8  nonCovidOccupiedMVBeds    NaN
# 9   2020-01-03       RXL  nonCovidOccupiedMVBeds    NaN
# 10  2020-01-03       RR8  nonCovidOccupiedMVBeds    NaN
# 11  2020-01-03       REM  nonCovidOccupiedMVBeds    NaN
# 12  2020-01-03       RNK  nonCovidOccupiedMVBeds    NaN
# 13  2020-01-03       RGT  nonCovidOccupiedMVBeds    NaN
# 14  2020-01-03      NRH8  nonCovidOccupiedMVBeds    NaN
# 15  2020-01-03       RXK  nonCovidOccupiedMVBeds    NaN
# ...

# %%
readme['date'] = pd.to_numeric(readme['date'])

# %%
readme.head(20)
# Out:
#                    date area_code                  metric  value
# 0   1578009600000000000       RNS  nonCovidOccupiedMVBeds    NaN
# 1   1578009600000000000       RGP  nonCovidOccupiedMVBeds    NaN
# 2   1578009600000000000       RP5  nonCovidOccupiedMVBeds    NaN
# 3   1578009600000000000       RJR  nonCovidOccupiedMVBeds    NaN
# 4   1578009600000000000       RLT  nonCovidOccupiedMVBeds    NaN
# 5   1578009600000000000       RXP  nonCovidOccupiedMVBeds    NaN
# 6   1578009600000000000       RKL  nonCovidOccupiedMVBeds    NaN
# 7   1578009600000000000      NRR8  nonCovidOccupiedMVBeds    NaN
# 8   1578009600000000000       RH8  nonCovidOccupiedMVBeds    NaN
# 9   1578009600000000000       RXL  nonCovidOccupiedMVBeds    NaN
# 10  1578009600000000000       RR8  nonCovidOccupiedMVBeds    NaN
# 11  1578009600000000000       REM  nonCovidOccupiedMVBeds    NaN
# 12  1578009600000000000       RNK  nonCovidOccupiedMVBeds    NaN
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

"""
To create Figure with an Axes is using:  pyplot.subplots
To Draw some data on Axes use: Axes.plot
To display the figure running: plt.show() 
"""

# %%
figure, axa = plt.subplots()  
axa.plot([1, 2, 3, 4], [1, 4, 2, 3], [4, 3, 2, 1], [2, 4, 3, 1])
plt.show()

# %%
figs = plt.figure()
figs, axa = plt.subplots()
figs, axs = plt.subplots(4,4)
figs, axs = plt.subplot_mosaic([['left', 'right_top'], ['left', 'right_bottom']])

# %%
figs_1 = plt.figure()

figs_1, axa_1 = plt.subplots()

figs_1, axs_1 = plt.subplots(3,3)

figs_1, axa_1 = plt.subplot_mosaic([['right', 'left_top'], ['right', 'left_bottom']])

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.patches import ConnectionPatch

fpart, (ax1, ax2) = plt.subplots(1, 2, figsize=(5, 10))
fpart.subplots_adjust(wspace=0)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpart, (ax1, ax2) = plt.subplots(1, 2, figsize=(3, 5))

xpart.subplots_adjust(wspace=0)


plt.show()

# %%
figs = plt.figure()
figs, axa = plt.subplots()
figs, axs = plt.subplots(3)
figs, axs = plt.subplot_mosaic([['left', 'right_top']])

# %%
figs = plt.figure()
figs, axa = plt.subplots()
figs, axs = plt.subplots(5)
figs, axs = plt.subplot_mosaic([['left', 'right_buttom']])
