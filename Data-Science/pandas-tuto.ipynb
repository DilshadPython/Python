# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.3.3

# %% [markdown]
# # Pandas
# data = pd.Series([0.25, 0.5, 0.75, 1.0], index=['a', 'b', 'c', 'd'])
#
# data.values
#
# data.index

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0], index=['a', 'b', 'c', 'd'])

data.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
data.values
# Out:
# array([0.25, 0.5 , 0.75, 1.  ])

# %%
a = pd.Series([2,4,5,6], index=['a', 'b', 'c', 'd'])
a
# Out:
# a    2
# b    4
# c    5
# d    6
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
type(a.values)
# Out:
# numpy.ndarray

# %%
a.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
a['a']
# Out:
# np.int64(2)

# %%
a['c']
# Out:
# np.int64(5)

# %%
a['a':'c']
# Out:
# a    2
# b    4
# c    5
# dtype: int64

# %% [markdown]
# Pandas(Series)
#
# Tutorials: https://www.geeksforgeeks.org/pandas/pandas-tutorial/
# DataFrame Libirary
# grades_dict = {'A':5.3, 'a': 65, 'B': 80, 'B-': 77, 'B': 77}
#
# grades = pd.Series(grades_dict)
#
# marks_dict = {'A': 81, 'A+': 86, 'B': 73, 'B+': 77, 'C': 65, 'C+': 66}
#
# markes = pd.Series(marks_dict)
#
# ## Titanic data
# https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html#min-tut-03-subset
#
# ## plots in pandas:
# https://pandas.pydata.org/docs/getting_started/intro_tutorials/04_plotting.html#min-tut-04-plotting
#
# ## create new columns and raws:
# https://pandas.pydata.org/docs/getting_started/intro_tutorials/05_add_columns.html#min-tut-05-columns

# %%
grades_dict = {'A':5.3, 'a': 65, 'B': 80, 'B-': 77, 'B': 77}

# %%
grades_dict
# Out:
# {'A': 5.3, 'a': 65, 'B': 77, 'B-': 77}

# %%
grades = pd.Series(grades_dict)

# %%
grades
# Out:
# A      5.3
# a     65.0
# B     77.0
# B-    77.0
# dtype: float64

# %%
marks_dict = {'A': 81, 'A+': 86, 'B': 73, 'B+': 77, 'C': 65, 'C+': 66}

marks = pd.Series(marks_dict)

marks
# Out:
# A     81
# A+    86
# B     73
# B+    77
# C     65
# C+    66
# dtype: int64

# %%
marks.values
# Out:
# array([81, 86, 73, 77, 65, 66])

# %% [raw]
# grades_dict = {'A':5.3, 'A-': 44, 'A+': 5, 'B': 80, 'B-': 77, 'B+': 66,'C': 65, 'C+': 67}

# %%
marks[0:4]
# Out:
# A     81
# A+    86
# B     73
# B+    77
# dtype: int64

# %%
marks[::-1]
# Out:
# C+    66
# C     65
# B+    77
# B     73
# A+    86
# A     81
# dtype: int64

# %% [markdown]
# grades = pd.Series(grades_dict)

# %%
grades
# Out:
# A      5.3
# a     65.0
# B     77.0
# B-    77.0
# dtype: float64

# %%
grades.values
# Out:
# array([ 5.3, 65. , 77. , 77. ])

# %%
grades[0:3]
# Out:
# A     5.3
# a    65.0
# B    77.0
# dtype: float64

# %%
grades[::-1]
# Out:
# B-    77.0
# B     77.0
# a     65.0
# A      5.3
# dtype: float64

# %%
markes_dict = {'A-': 81, 'A': 85,'A+': 86, 'B-': 72, 'B': 75, 'B+': 77, 'C': 65, 'C+': 66}
marks = pd.Series(markes_dict)

# %%
marks
# Out:
# A-    81
# A     85
# A+    86
# B-    72
# B     75
# B+    77
# C     65
# C+    66
# dtype: int64

# %%
marks[::-1]
# Out:
# C+    66
# C     65
# B+    77
# B     75
# B-    72
# A+    86
# A     85
# A-    81
# dtype: int64

# %%
marks.index
# Out:
# Index(['A-', 'A', 'A+', 'B-', 'B', 'B+', 'C', 'C+'], dtype='object')

# %%
marks.values
# Out:
# array([81, 85, 86, 72, 75, 77, 65, 66])

# %%
marks[0:5]
# Out:
# A-    81
# A     85
# A+    86
# B-    72
# B     75
# dtype: int64

# %%
results = pd.DataFrame({'grades': grades, 'marks': marks})

# %%
results
# Out:
#     grades  marks
# A      5.3   85.0
# A+     NaN   86.0
# A-     NaN   81.0
# B     77.0   75.0
# B+     NaN   77.0
# B-    77.0   72.0
# C      NaN   65.0
# C+     NaN   66.0
# a     65.0    NaN

# %% [markdown]
# # Pandas(csv files)
# import pandas as pd
#
# import numpy as np
#
# from sklearn.impute import Simplelmputer data_frame = pd.read_csv('covid_19_data.csv')

# %% [markdown]
# import pandas as pd
# import numpy as np
# import sklearn
#
# from sklearn.impute import Simplelmputer
#
# data_frame = pd.read_csv('nonSentinelTestsDetections.csv')
#
# data_frame.drop(['SNo', 'Last Update'], axis=1, inplace=True)
#
# data_frame.rename(columns={'ObervationDate':'Date', 'Province/State':'State', 'Country/Region':'Country'}, inplace=True)
#
# data_frame['Date'] = pd.to_datetime(data_frame['Date'])
#
# imputer = SimpleImputer(strategy='constant')
#
# data_frame_1 = pd.DataFrame(imputer.fit_transform(data_frame), columns=data_frame.columns)
#
# data_frame_2 = data_frame_1.groupby(['Date', 'Country'])[['Date', 'Country', 'Confirmed', 'Deaths', 'Recovered']].sum.reset_index()
#
# data_frame_3 = data_frame_2.groupby(['Date', 'Country'])[['Date', 'Country', 'Confirmed', 'Deaths', 'Recovered']].sum.reset_index()
#
# data_frame_3.head(20)

# %%
# You have to install sklearn pip install >> pip install scikit-learn
import pandas as pd 
import numpy as np 
import sklearn

from sklearn.impute import SimpleImputer


# Find the path of the file
csv_path = '/home/monika/Devop/Python/Data-Science/'

csv_name = csv_path + "nonSentinelTestsDetections.csv"

df = pd.read_csv(csv_name)

# %%
df
# Out:
#            survtype countryname  yearweek    pathogen pathogentype  \
# 0      non-sentinel     Austria  2025-W43   Influenza    Influenza
# 1      non-sentinel     Austria  2025-W43   Influenza    Influenza
# 2      non-sentinel     Austria  2025-W43   Influenza  Influenza A
# 3      non-sentinel     Austria  2025-W43   Influenza  Influenza B
# 4      non-sentinel     Austria  2025-W43         RSV          RSV
# ...             ...         ...       ...         ...          ...
# 97391  non-sentinel      Sweden  2021-W25  SARS-CoV-2   SARS-CoV-2
# 97392  non-sentinel      Sweden  2021-W25  SARS-CoV-2   SARS-CoV-2
# 97393  non-sentinel      Sweden  2021-W25  SARS-CoV-2   SARS-CoV-2
# 97394  non-sentinel      Sweden  2021-W25  SARS-CoV-2   SARS-CoV-2
# 97395  non-sentinel      Sweden  2021-W25  SARS-CoV-2   SARS-CoV-2
#
#       pathogensubtype   indicator    age   value
# 0               total  detections  total       4
# 1               total       tests  total     272
# ...

# %%
df.head(15)
# Out:
#         survtype countryname  yearweek    pathogen pathogentype  \
# 0   non-sentinel     Austria  2025-W43   Influenza    Influenza
# 1   non-sentinel     Austria  2025-W43   Influenza    Influenza
# 2   non-sentinel     Austria  2025-W43   Influenza  Influenza A
# 3   non-sentinel     Austria  2025-W43   Influenza  Influenza B
# 4   non-sentinel     Austria  2025-W43         RSV          RSV
# 5   non-sentinel     Austria  2025-W43         RSV          RSV
# 6   non-sentinel     Austria  2025-W43         RSV  RSV untyped
# 7   non-sentinel     Austria  2025-W43  SARS-CoV-2   SARS-CoV-2
# 8   non-sentinel     Austria  2025-W43  SARS-CoV-2   SARS-CoV-2
# 9   non-sentinel     Austria  2025-W43  SARS-CoV-2   SARS-CoV-2
# 10  non-sentinel     Austria  2025-W43  SARS-CoV-2   SARS-CoV-2
# 11  non-sentinel     Austria  2025-W43  SARS-CoV-2   SARS-CoV-2
# 12  non-sentinel     Austria  2025-W43  SARS-CoV-2   SARS-CoV-2
# 13  non-sentinel     Austria  2025-W43  SARS-CoV-2   SARS-CoV-2
# ...

# %%
df.drop(['survtype'], axis=1, inplace=True)

# %%
df
# Out:
#       countryname  yearweek    pathogen   indicator    age   value
# 0         Austria  2025-W43   Influenza  detections  total       4
# 1         Austria  2025-W43   Influenza       tests  total     272
# 2         Austria  2025-W43   Influenza  detections  total       3
# 3         Austria  2025-W43   Influenza  detections  total       1
# 4         Austria  2025-W43         RSV  detections  total       1
# ...           ...       ...         ...         ...    ...     ...
# 97391      Sweden  2021-W25  SARS-CoV-2       tests    0-4     881
# 97392      Sweden  2021-W25  SARS-CoV-2       tests  15-64   71679
# 97393      Sweden  2021-W25  SARS-CoV-2       tests   5-14    8737
# 97394      Sweden  2021-W25  SARS-CoV-2       tests    65+   12851
# 97395      Sweden  2021-W25  SARS-CoV-2       tests  total  100822
#
# [97396 rows x 6 columns]

# %%
df.drop(['pathogen', 'age'], axis=1, inplace=True)

# %%
df.head(15)
# Out:
#    countryname  yearweek   indicator  value
# 0      Austria  2025-W43  detections      4
# 1      Austria  2025-W43       tests    272
# 2      Austria  2025-W43  detections      3
# 3      Austria  2025-W43  detections      1
# 4      Austria  2025-W43  detections      1
# 5      Austria  2025-W43       tests    420
# 6      Austria  2025-W43  detections      1
# 7      Austria  2025-W43  detections      0
# 8      Austria  2025-W43  detections      0
# 9      Austria  2025-W43  detections      0
# 10     Austria  2025-W43  detections      0
# 11     Austria  2025-W43  detections     44
# 12     Austria  2025-W43       tests      0
# 13     Austria  2025-W43       tests      0
# 14     Austria  2025-W43       tests      0

# %%
df
# Out:
#       countryname  yearweek   indicator   value
# 0         Austria  2025-W43  detections       4
# 1         Austria  2025-W43       tests     272
# 2         Austria  2025-W43  detections       3
# 3         Austria  2025-W43  detections       1
# 4         Austria  2025-W43  detections       1
# ...           ...       ...         ...     ...
# 97391      Sweden  2021-W25       tests     881
# 97392      Sweden  2021-W25       tests   71679
# 97393      Sweden  2021-W25       tests    8737
# 97394      Sweden  2021-W25       tests   12851
# 97395      Sweden  2021-W25       tests  100822
#
# [97396 rows x 4 columns]

# %%
df.rename(columns={'countryname':'COUNTRY', 'yearweek':'YEAR & WEEKS'}, inplace=True)

# %%
df.head(15)
# Out:
#     COUNTRY YEAR & WEEKS   indicator  value
# 0   Austria     2025-W43  detections      4
# 1   Austria     2025-W43       tests    272
# 2   Austria     2025-W43  detections      3
# 3   Austria     2025-W43  detections      1
# 4   Austria     2025-W43  detections      1
# 5   Austria     2025-W43       tests    420
# 6   Austria     2025-W43  detections      1
# 7   Austria     2025-W43  detections      0
# 8   Austria     2025-W43  detections      0
# 9   Austria     2025-W43  detections      0
# 10  Austria     2025-W43  detections      0
# 11  Austria     2025-W43  detections     44
# 12  Austria     2025-W43       tests      0
# 13  Austria     2025-W43       tests      0
# 14  Austria     2025-W43       tests      0

# %%
data_frame = pd.read_csv(csv_name)

# %%
data_frame
# Out:
#            survtype countryname  yearweek    pathogen pathogentype  \
# 0      non-sentinel     Austria  2025-W43   Influenza    Influenza
# 1      non-sentinel     Austria  2025-W43   Influenza    Influenza
# 2      non-sentinel     Austria  2025-W43   Influenza  Influenza A
# 3      non-sentinel     Austria  2025-W43   Influenza  Influenza B
# 4      non-sentinel     Austria  2025-W43         RSV          RSV
# ...             ...         ...       ...         ...          ...
# 97391  non-sentinel      Sweden  2021-W25  SARS-CoV-2   SARS-CoV-2
# 97392  non-sentinel      Sweden  2021-W25  SARS-CoV-2   SARS-CoV-2
# 97393  non-sentinel      Sweden  2021-W25  SARS-CoV-2   SARS-CoV-2
# 97394  non-sentinel      Sweden  2021-W25  SARS-CoV-2   SARS-CoV-2
# 97395  non-sentinel      Sweden  2021-W25  SARS-CoV-2   SARS-CoV-2
#
#       pathogensubtype   indicator    age   value
# 0               total  detections  total       4
# 1               total       tests  total     272
# ...

# %%
data_frame = pd.read_csv(csv_name)
print(data_frame.head(40))
# Out:
#         survtype countryname  yearweek    pathogen pathogentype  \
# 0   non-sentinel     Austria  2025-W43   Influenza    Influenza
# 1   non-sentinel     Austria  2025-W43   Influenza    Influenza
# 2   non-sentinel     Austria  2025-W43   Influenza  Influenza A
# 3   non-sentinel     Austria  2025-W43   Influenza  Influenza B
# 4   non-sentinel     Austria  2025-W43         RSV          RSV
# 5   non-sentinel     Austria  2025-W43         RSV          RSV
# 6   non-sentinel     Austria  2025-W43         RSV  RSV untyped
# 7   non-sentinel     Austria  2025-W43  SARS-CoV-2   SARS-CoV-2
# 8   non-sentinel     Austria  2025-W43  SARS-CoV-2   SARS-CoV-2
# 9   non-sentinel     Austria  2025-W43  SARS-CoV-2   SARS-CoV-2
# 10  non-sentinel     Austria  2025-W43  SARS-CoV-2   SARS-CoV-2
# 11  non-sentinel     Austria  2025-W43  SARS-CoV-2   SARS-CoV-2
# 12  non-sentinel     Austria  2025-W43  SARS-CoV-2   SARS-CoV-2
# 13  non-sentinel     Austria  2025-W43  SARS-CoV-2   SARS-CoV-2
# ...

# %%
data_frame.describe()
# Out:
#               value
# count  9.739600e+04
# mean   4.267514e+04
# std    6.080696e+05
# min    0.000000e+00
# 25%    3.000000e+00
# 50%    7.100000e+01
# 75%    1.355000e+03
# max    4.670350e+07

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97396 entries, 0 to 97395
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   survtype         97396 non-null  object
#  1   countryname      97396 non-null  object
#  2   yearweek         97396 non-null  object
#  3   pathogen         97396 non-null  object
#  4   pathogentype     97396 non-null  object
#  5   pathogensubtype  93128 non-null  object
#  6   indicator        97396 non-null  object
#  7   age              97396 non-null  object
#  8   value            97396 non-null  int64
# dtypes: int64(1), object(8)
# memory usage: 6.7+ MB

# %%
data_frame.index
# Out:
# RangeIndex(start=0, stop=97396, step=1)

# %%
data_frame.infer_objects
# Out:
# <bound method NDFrame.infer_objects of            survtype countryname  yearweek    pathogen pathogentype  \
# 0      non-sentinel     Austria  2025-W43   Influenza    Influenza
# 1      non-sentinel     Austria  2025-W43   Influenza    Influenza
# 2      non-sentinel     Austria  2025-W43   Influenza  Influenza A
# 3      non-sentinel     Austria  2025-W43   Influenza  Influenza B
# 4      non-sentinel     Austria  2025-W43         RSV          RSV
# ...             ...         ...       ...         ...          ...
# 97391  non-sentinel      Sweden  2021-W25  SARS-CoV-2   SARS-CoV-2
# 97392  non-sentinel      Sweden  2021-W25  SARS-CoV-2   SARS-CoV-2
# 97393  non-sentinel      Sweden  2021-W25  SARS-CoV-2   SARS-CoV-2
# 97394  non-sentinel      Sweden  2021-W25  SARS-CoV-2   SARS-CoV-2
# 97395  non-sentinel      Sweden  2021-W25  SARS-CoV-2   SARS-CoV-2
#
#       pathogensubtype   indicator    age   value
# 0               total  detections  total       4
# ...

# %%
dataf = data_frame.fillna('NA')

# %%
dataf
# Out:
#            survtype countryname  yearweek    pathogen pathogentype  \
# 0      non-sentinel     Austria  2025-W43   Influenza    Influenza
# 1      non-sentinel     Austria  2025-W43   Influenza    Influenza
# 2      non-sentinel     Austria  2025-W43   Influenza  Influenza A
# 3      non-sentinel     Austria  2025-W43   Influenza  Influenza B
# 4      non-sentinel     Austria  2025-W43         RSV          RSV
# ...             ...         ...       ...         ...          ...
# 97391  non-sentinel      Sweden  2021-W25  SARS-CoV-2   SARS-CoV-2
# 97392  non-sentinel      Sweden  2021-W25  SARS-CoV-2   SARS-CoV-2
# 97393  non-sentinel      Sweden  2021-W25  SARS-CoV-2   SARS-CoV-2
# 97394  non-sentinel      Sweden  2021-W25  SARS-CoV-2   SARS-CoV-2
# 97395  non-sentinel      Sweden  2021-W25  SARS-CoV-2   SARS-CoV-2
#
#       pathogensubtype   indicator    age   value
# 0               total  detections  total       4
# 1               total       tests  total     272
# ...

# %%
dataf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97396 entries, 0 to 97395
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   survtype         97396 non-null  object
#  1   countryname      97396 non-null  object
#  2   yearweek         97396 non-null  object
#  3   pathogen         97396 non-null  object
#  4   pathogentype     97396 non-null  object
#  5   pathogensubtype  97396 non-null  object
#  6   indicator        97396 non-null  object
#  7   age              97396 non-null  object
#  8   value            97396 non-null  int64
# dtypes: int64(1), object(8)
# memory usage: 6.7+ MB

# %%
data_frame.head(12)
# Out:
#         survtype countryname  yearweek    pathogen pathogentype  \
# 0   non-sentinel     Austria  2025-W43   Influenza    Influenza
# 1   non-sentinel     Austria  2025-W43   Influenza    Influenza
# 2   non-sentinel     Austria  2025-W43   Influenza  Influenza A
# 3   non-sentinel     Austria  2025-W43   Influenza  Influenza B
# 4   non-sentinel     Austria  2025-W43         RSV          RSV
# 5   non-sentinel     Austria  2025-W43         RSV          RSV
# 6   non-sentinel     Austria  2025-W43         RSV  RSV untyped
# 7   non-sentinel     Austria  2025-W43  SARS-CoV-2   SARS-CoV-2
# 8   non-sentinel     Austria  2025-W43  SARS-CoV-2   SARS-CoV-2
# 9   non-sentinel     Austria  2025-W43  SARS-CoV-2   SARS-CoV-2
# 10  non-sentinel     Austria  2025-W43  SARS-CoV-2   SARS-CoV-2
# 11  non-sentinel     Austria  2025-W43  SARS-CoV-2   SARS-CoV-2
#
#    pathogensubtype   indicator    age  value
# 0            total  detections  total      4
# ...

# %%
data_frame_a = data_frame.groupby('countryname')[['yearweek', 'pathogen', 'age', 'value']].sum().reset_index()

# %%
data_frame_a
# Out:
#       countryname                                           yearweek  \
# 0         Austria  2025-W432025-W432025-W432025-W432025-W432025-W...
# 1         Belgium  2025-W452025-W452025-W452025-W452025-W452025-W...
# 2        Bulgaria  2025-W452025-W452025-W452025-W452025-W452025-W...
# 3         Croatia  2025-W452025-W452025-W452025-W452025-W452025-W...
# 4          Cyprus  2025-W452025-W452025-W452025-W452025-W452025-W...
# 5         Czechia  2025-W452025-W452025-W452025-W452025-W452025-W...
# 6         Denmark  2025-W452025-W452025-W452025-W452025-W452025-W...
# 7          EU/EEA  2025-W452025-W452025-W452025-W452025-W452025-W...
# 8         Estonia  2025-W452025-W452025-W452025-W452025-W452025-W...
# 9         Finland  2025-W432025-W432025-W432025-W432025-W432025-W...
# 10         France  2025-W442025-W442025-W442025-W442025-W442025-W...
# 11        Germany  2025-W452025-W452025-W452025-W452025-W452025-W...
# 12         Greece  2025-W452025-W452025-W452025-W452025-W452025-W...
# ...

# %%
data_frame_b = data_frame.groupby(['countryname', 'yearweek'])[['pathogen', 'age', 'value']].sum().reset_index()

# %%
data_frame_b
# Out:
#      countryname  yearweek                                           pathogen  \
# 0        Austria  2021-W25  SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-C...
# 1        Austria  2021-W26  SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-C...
# 2        Austria  2021-W27  SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-C...
# 3        Austria  2021-W28  SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-C...
# 4        Austria  2021-W29  SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-C...
# ...          ...       ...                                                ...
# 6929      Sweden  2025-W41  InfluenzaInfluenzaInfluenzaInfluenzaInfluenzaR...
# 6930      Sweden  2025-W42  InfluenzaInfluenzaInfluenzaInfluenzaInfluenzaI...
# 6931      Sweden  2025-W43  InfluenzaInfluenzaInfluenzaInfluenzaInfluenzaI...
# 6932      Sweden  2025-W44  InfluenzaInfluenzaInfluenzaInfluenzaInfluenzaI...
# 6933      Sweden  2025-W45  InfluenzaInfluenzaInfluenzaInfluenzaInfluenzaI...
#
# ...

# %%
data_frame_c = data_frame_b[data_frame_b['value']>2000]

# %%
data_frame_c.head(50)
# Out:
#    countryname  yearweek                                           pathogen  \
# 2      Austria  2021-W27  SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-C...
# 3      Austria  2021-W28  SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-C...
# 4      Austria  2021-W29  SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-C...
# 5      Austria  2021-W30  SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-C...
# 6      Austria  2021-W31  SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-C...
# 7      Austria  2021-W32  SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-C...
# 8      Austria  2021-W33  SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-C...
# 9      Austria  2021-W34  SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-C...
# 10     Austria  2021-W35  SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-C...
# 11     Austria  2021-W36  SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-C...
# 12     Austria  2021-W37  SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-CoV-2SARS-C...
# ...
